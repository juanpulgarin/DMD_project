# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import scipy.linalg as LA

import Hamiltonian as Hamiltonian
import DMD_scripts as dmd_scripts
import Plotting as plotting
import constants as cst


from pydmd import DMD, BOPDMD
from pydmd.plotter import plot_eigs, plot_summary
from pydmd.preprocessing import hankel_preprocessing

# %% [markdown]
# ### This section shows what happens when changing the different parameters in your Hamiltonian

# %%
k_vals = np.linspace(-np.pi, np.pi, 101)[:-1]

J_list     = np.array([1.0])/cst.Ry
delta_list = np.array([0.5,1.5])/cst.Ry

valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-3.5,3.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')

for J in J_list:
    for Δ in delta_list:
        plotting.plot_band_structure(k_vals, np.array([J]), np.array([Δ]), valence_bands, conduction_bands, limits,fout='')



J_list     = np.array([1.0,2.5])/cst.Ry
delta_list = np.array([0.5])/cst.Ry


valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-3.5,3.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')

for J in J_list:
    for Δ in delta_list:
        plotting.plot_band_structure(k_vals, np.array([J]), np.array([Δ]), valence_bands, conduction_bands, limits,fout='')

# %% [markdown]
# ### Fix a set of parameters for the Bands, then change the values of the Field and the case

# %%
k_vals = np.linspace(-np.pi, np.pi, 101)[:-1]

J_list     = np.array([0.5])/cst.Ry
delta_list = np.array([0.5])/cst.Ry

valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-2.5,2.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')
# Out:
# 0

# %%
case=1

t = np.linspace(0, 100, 10000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 1.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J     = 0.5/cst.Ry
delta = 0.5/cst.Ry
k_list=[0, 0.25, 0.50, 0.75]


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),2,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]

# %%
limits=np.array([[0,100],[0.0,0.2]])
plotting.plot_population_field(t*cst.tfs,efield,k_list,solutions.real,limits)
# Out:
# 0

# %%
case=2

t = np.linspace(0, 100, 1000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 0.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J     = 0.5/cst.Ry
delta = 0.5/cst.Ry
k_list=[0, 0.25, 0.50, 0.75]


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),2,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]

# %%
limits=np.array([[0,100],[0.0,0.2]])
plotting.plot_population_field(t*cst.tfs,efield,k_list,solutions.real,limits)
# Out:
# 0

# %% [markdown]
# ### After fixing a case, test the DMD algorithm

# %%
case=1

t = np.linspace(0, 100, 10000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 1.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J      = 0.5/cst.Ry
delta  = 0.5/cst.Ry
k_list = np.linspace(-np.pi, np.pi, 101)[:-1]


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),2,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]

# %%
X = solutions[:,0,:-1]
Y = solutions[:,0,1: ]

truncamiento=-6

#eigvals, Phi_L, r_L, S      = Hamiltonian.perform_dmd(X, Y, t, 3)
mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y,orden_truncado=[0,truncamiento])

# %%
plotting.plot_singular_values(Sig2,10**(truncamiento))
plotting.plot_eigenvalues(mu)
# Out:
# 0

# %%
X = solutions[:,0,:-1]
Y = solutions[:,0,1: ]

truncamiento=-6


mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y, orden_truncado=[0,truncamiento])

# Time evolution from DMD output
dt = t[1] - t[0]
omega_M = np.log(mu) / dt
b_M = np.linalg.pinv(Phi_M) @ X[:, 0]
time_dynamics_M = np.array([b_M * np.exp(omega_M * T) for T in t]).T
X_dmd_M = Phi_M @ time_dynamics_M

# %%
plt.plot(X_dmd_M[0,:])
# Out:
# /home/juanmosquera/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/juanmosquera/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plotting.plot_singular_values(Sig2,10**(truncamiento))
plotting.plot_eigenvalues(mu)
# Out:
# 0

# %%
from pydmd import DMD
from pydmd.plotter import plot_eigs, plot_summary
from pydmd.preprocessing import hankel_preprocessing

# %%
# ========= Apply DMD ===========
rank=11
#truncamiento=-6


eigvals, Phi_L, r_L, S      = Hamiltonian.perform_dmd(X, Y, t, rank)
mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y,orden_truncado=[1,rank],truncate=True)
plotting.plot_singular_values(Sig2,rank, False) 
plotting.plot_eigenvalues(mu)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       6 eigvals, Phi_L, r_L, S      = Hamiltonian.perform_dmd(X, Y, t, rank)
#       7 mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y,orden_truncado=[1,rank],truncate=True)
# ----> 8 plotting.plot_singular_values(Sig2,rank, False)
#       9 plotting.plot_eigenvalues(mu)
#
# File ~/DMD_project/Scripts/Plotting.py:142, in plot_singular_values(sigma, truncado, fout)
#     139 axs.spines['top'].set_visible(False)
#     140 axs.spines['right'].set_visible(False)
# --> 142 if len(fout) > 0:
#     143     plt.savefig(fout+'.png', bbox_inches='tight', transparent=True)
#     144     plt.savefig(fout+'.pdf', bbox_inches='tight', transparent=True)
#
# TypeError: object of type 'bool' has no len()

# %%
delay = 10  # we will use this number of delays throughout the tutorial         
dmd = DMD(svd_rank=4)
delay_dmd = hankel_preprocessing(dmd, d=delay)
delay_dmd.fit(X)
# Out:
# /home/juanmosquera/Library/PyDMD/pydmd/snapshots.py:73: UserWarning: Input data condition number 1.2568365887665832e+27. Consider preprocessing data, passing in augmented data
# matrix, or regularization methods.
#   warnings.warn(

# %%
X = solutions[:,0,:-1]
Y = solutions[:,0,1: ]

truncamiento=-6

#eigvals, Phi_L, r_L, S      = Hamiltonian.perform_dmd(X, Y, t, 3)
mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y,orden_truncado=[0,truncamiento])

# %%
import warnings

warnings.filterwarnings("ignore")


from pydmd import DMD
from pydmd.plotter import plot_eigs, plot_summary
from pydmd.preprocessing import hankel_preprocessing



# ====== Set up the simulation ======
#-------------- Simple Pulse 3 / Band structure 2--------------

#Get the simualtion ready for DMD use:
t_dmd = t[:-1]  # because X and Y have 999 time steps
X = solutions[:, 0, :-1]  # shape: (num_k, len(t)-1)
Y = solutions[:, 0, 1:]   # one step ahead




# ========= Apply DMD ===========
rank=11
index=50

delay = 400  # we will use this number of delays throughout the tutorial         
dmd = DMD(svd_rank=rank)
delay_dmd = hankel_preprocessing(dmd, d=delay)
delay_dmd.fit(X)

# Reconstruction
X_dmd = dmd.reconstructed_data.real  # or .imag or .abs()
# Optional: get eigenvalues or modes
eigs = dmd.eigs
modes = dmd.modes

# Chop the first 399 time points to align with DMD output
t_dmd_shifted = t_dmd[:600]
#t_dmd_shifted = t_dmd[delay-1:] #use this line instead of the line above and DMD will stop working (also reset delay=2)

# Truncate DMD data to match the shortened time axis
x_dmd_shifted = X_dmd[index].real[:len(t_dmd_shifted)] 

eigvals, Phi_L, r_L, S      = Hamiltonian.perform_dmd(X, Y, t, rank)
mu, Phi_M, r_M, Sig2 = Hamiltonian.DMD(X, Y, False, orden_truncado=rank)

# Plot
plotting.plot_singular_values(Sig2,rank, False) 
plotting.plot_eigenvalues(mu)
plt.plot(t_dmd, X[index].real, label="Original", alpha=0.6)
plt.plot(t_dmd_shifted, x_dmd_shifted, label=f"Delay_DMD Reconstructed for rank={rank}", linestyle='--')
plt.title(f"Reconstruction at index={index} (DMD shifted to start at t=0)")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from pydmd.preprocessing import hankel_preprocessing

# 1. Generate synthetic data
t = np.linspace(0, 10, 200)
X = np.sin(2 * np.pi * 0.5 * t) + 0.3 * np.sin(2 * np.pi * 1.5 * t)
X = X.reshape(1, -1)  # Shape: (1, 200)

# 2. Custom Hankel embedding function
def custom_hankel_embedding(X, delay):
    """
    Create Hankel matrix from data matrix X (shape n x m)
    with 'delay' number of rows in the embedding.
    Returns: (delay*n) x (m - delay + 1)
    """
    n, m = X.shape
    hankel_matrix = np.vstack([X[:, i: m - delay + i + 1] for i in range(delay)])
    return hankel_matrix

delay = 10

# Apply custom Hankel embedding
H_custom = custom_hankel_embedding(X, delay)

# 3. Apply PyDMD's preprocessing
from pydmd import DMD
dmd = DMD(svd_rank=0)
delay_dmd = hankel_preprocessing(dmd, d=delay)
delay_dmd.fit(X)

# PyDMD's internal Hankel matrix
H_pydmd = delay_dmd.snapshots

# 4. Compare both matrices
print("Are they approximately equal?", np.allclose(H_custom, H_pydmd))

# Optional: visualize the result
plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.imshow(H_custom, aspect='auto')
plt.title("Custom Hankel Embedding")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(H_pydmd, aspect='auto')
plt.title("PyDMD Hankel Embedding")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(H_custom-H_pydmd, aspect='auto')
plt.title("Diff")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# /home/juanmosquera/Library/PyDMD/pydmd/snapshots.py:73: UserWarning: Input data condition number 2850508337357194.5. Consider preprocessing data, passing in augmented data
# matrix, or regularization methods.
#   warnings.warn(
# Are they approximately equal? True

# %%
from pydmd.plotter import plot_eigs, plot_summary

def f1(x, t):
    return 1.0 / np.cosh(x + 3) * np.cos(2.3 * t)


def f2(x, t):
    return 2.0 / np.cosh(x) * np.tanh(x) * np.sin(2.8 * t)


nx = 65  # number of grid points along space dimension
nt = 129  # number of grid points along time dimension

# Define the space and time grid for data collection.
x = np.linspace(-5, 5, nx)
t = np.linspace(0, 4 * np.pi, nt)
xgrid, tgrid = np.meshgrid(x, t)
dt = t[1] - t[0]  # time step between each snapshot

# Data consists of 2 spatiotemporal signals.
X1 = f1(xgrid, tgrid)
X2 = f2(xgrid, tgrid)
X = X1 + X2

# Make a version of the data with noise.
mean = 0
std_dev = 0.2
random_matrix = np.random.normal(mean, std_dev, size=(nt, nx))
Xn = X + random_matrix

# %%
#---------------------------------------------------------------
import scipy.linalg as LA

def custom_hankel_embedding(X, delay):
    n, m = X.shape
    hankel_matrix = np.vstack([
        X[:, i: m - delay + i + 1] for i in range(delay)
    ])
    return hankel_matrix

def perform_dmd(H, rank=None, d=1, dt=1):
    #print(np.shape(H))
    X1 = H[:, :-1]
    X2 = H[:, 1:]

    U, S, Vh = svd(X1, full_matrices=False)

    if rank is not None:
        U_r  = U[:, :rank]
        S_r  = S[:rank]
        Vh_r = Vh[:rank, :]
    else:
        U_r  = U[:, :]
        S_r  = S[:]
        Vh_r = Vh[:, :]

    Sigma_inv = np.diag(1 / (S_r + 0.000001 ))
    A_tilde = U_r.T @ X2 @ Vh_r.T @ Sigma_inv
    eigvals, W = LA.eig(A_tilde)
    Phi = X2 @ Vh_r.T @ Sigma_inv @ W
    if d > 1:
        Φ = np.average( Phi.reshape(d,Phi.shape[0] // d, Phi.shape[1],),axis=0,)
    
    

    

    return S,eigvals,Phi, Φ
    #x0 = X1[:, 0]
    #b = pinv(Phi) @ x0
    #omega = np.log(eigvals) / dt
    #timesteps = np.arange(X1.shape[1]) * dt + t0
    #print(timesteps)
    #time_dynamics = np.array([b * np.exp(omega * t) for t in timesteps]).T

    #X_dmd = Phi @ time_dynamics
    #return eigvals, Phi, X_dmd.real, timesteps


def Dynamics(H,Eigvals,Φ,nt,d):
    x1=H[:,0]

    time_steps = np.linspace(0,nt-d,nt-d+1,dtype=int)
    temp = np.repeat( Eigvals[:, None], time_steps.shape[0], axis=1 )
    tpow = ( time_steps - 0 ) / ( time_steps[1] - time_steps[0] )

    amplitudes = LA.pinv(Φ) @ x1
    dynamics = np.power(temp, tpow) * amplitudes[:, None]

    return temp, amplitudes, dynamics , np.dot(Φ,dynamics)


H_custom = custom_hankel_embedding(X.T, d)
Singular_values,Eigvals,Modes,modes_average = perform_dmd(H_custom, rank=rank, d=d )
temp_costum,amplitudes_costum,b_costum,reconstruction_costum = Dynamics(H_custom,Eigvals,Modes,nt,d)

print(np.shape(H_custom))


#---------------------------------------------------------------

print(np.shape(delay_dmd.modes))
print(np.argsort(-np.abs(dmd.amplitudes)),dmd.amplitudes,dmd.eigs)


mode_order = np.argsort(-np.abs(dmd.amplitudes))
lead_eigs = dmd.eigs[mode_order]
lead_modes = dmd.modes[:, mode_order]
lead_dynamics = dmd.dynamics[mode_order]
print("dmd_timesteps:",dmd.dmd_timesteps.shape[0])
print("original_time:",dmd.original_time)
print(dmd._opt)

print(np.shape(lead_modes))
#lead_modes = dmd.modes

if d > 1:
    lead_modes = np.average( lead_modes.reshape(d,lead_modes.shape[0] // d, lead_modes.shape[1],),axis=0,)
    #lead_modes = np.average( lead_modes.reshape(lead_modes.shape[0] // d,d, lead_modes.shape[1],),axis=1,)
print(np.shape(lead_modes))


temp = np.repeat(
            dmd.eigs[:, None], dmd.dmd_timesteps.shape[0], axis=1
        )



#-----------------------------------------------------

plt.figure()
plt.plot(x,lead_modes[:,0].real)
plt.plot(x,modes_average[:,0].real)

plt.figure()
plt.plot(lead_dynamics[3].real)
plt.plot(b_costum[3].real)

plt.figure()
plt.plot(amplitudes_costum.real,amplitudes_costum.imag,'o')
plt.plot(dmd.amplitudes.real,dmd.amplitudes.imag,'o')
# Out:
# /home/juanmosquera/Library/PyDMD/pydmd/snapshots.py:73: UserWarning: Input data condition number 1.539994674102876e+17. Consider preprocessing data, passing in augmented data
# matrix, or regularization methods.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 73
#      69     return temp, amplitudes, dynamics , np.dot(Φ,dynamics)
#      72 H_custom = custom_hankel_embedding(X.T, d)
# ---> 73 Singular_values,Eigvals,Modes,modes_average = perform_dmd(H_custom, rank=rank, d=d )
#      74 temp_costum,amplitudes_costum,b_costum,reconstruction_costum = Dynamics(H_custom,Eigvals,Modes,nt,d)
#      76 print(np.shape(H_custom))
#
# Cell In[4], line 25, in perform_dmd(H, rank, d, dt)
#      22 X1 = H[:, :-1]
#      23 X2 = H[:, 1:]
# ---> 25 U, S, Vh = svd(X1, full_matrices=False)
#      27 if rank is not None:
#      28     U_r  = U[:, :rank]
#
# ...

# %%
plt.figure(figsize=(12, 12))

plt.subplot(3, 2, 1)
plt.title("Eigenvalues: Custom vs PyDMD")
plt.plot(lead_eigs.real, lead_eigs.imag, 'go', label='PyDMD')
plt.plot(Eigvals.real, Eigvals.imag, 'r*', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 2)
plt.title("Singular Values")
plt.plot(np.log(Singular_values[:]/Singular_values[0]), 'g.', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 3)
plt.title("Eigenmodes")
plt.plot(dmd.amplitudes.real,dmd.amplitudes.imag, 'go', label='PyDMD')
plt.plot(amplitudes_costum.real, amplitudes_costum.imag, 'r*', label='Custom')
plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 4)
plt.imshow(np.dot(modes_average,b_costum).real)

plt.subplot(3, 2, 5)
plt.imshow(delay_dmd.reconstructed_data[0:65].real)

plt.subplot(3, 2, 6)
plt.imshow(reconstruction_costum[:,0:120].real)

# %%
#plt.plot(dmd.amplitudes.real,dmd.amplitudes.imag,'o')
#plt.plot(amplitudes_costum.real,amplitudes_costum.imag,'o')
modes_test = (dmd.modes)[:,3] #@ dmd.snapshots[:, 0]
print(modes_test.shape)
plt.plot(modes_test.real,modes_test.imag)
modes_test = (Modes)[:,3] #@ dmd.snapshots[:, 0]
print(modes_test.shape)
plt.plot(modes_test.real,modes_test.imag,'.')
print(dmd.amplitudes)
print(amplitudes_costum)
#print(np.allclose(dmd.snapshots[:, 0], H_custom[0:int(np.shape(H_custom)[0]/d),0], atol=1e-8)   )
#np.shape(H_custom[0:int(np.shape(H_custom)[0]/d),0])
plt.grid()
# Out:
# (650,)
# (650,)
# [-6.34637792+1.54280728j -6.34637792-1.54280728j  2.822481  +4.85200208j
#   2.822481  -4.85200208j]
# [-2.62298989e-08+3.64120454e-07j -2.62299011e-08-3.64120454e-07j
#   6.85893263e+00-1.37595860e+00j  6.85893263e+00+1.37595860e+00j]

# %%
d = 10  # we will use this number of delays throughout the tutorial
rank=4

#---------------------------------------------------------------

dmd = DMD(svd_rank=rank)
delay_dmd = hankel_preprocessing(dmd, d=d)
delay_dmd.fit(X.T)

mode_order = np.argsort(-np.abs(dmd.amplitudes))
lead_eigs = dmd.eigs[mode_order]
lead_modes = dmd.modes[:, mode_order]
lead_dynamics = dmd.dynamics[mode_order]
print("dmd_timesteps:",dmd.dmd_timesteps.shape[0])
print("original_time:",dmd.original_time)


H_custom = dmd_scripts.custom_hankel_embedding(X.T, d)
Singular_values,Eigvals,Modes,modes_average = dmd_scripts.perform_dmd(H_custom, rank=rank, d=d )
temp_costum,amplitudes_costum,b_costum,reconstruction_costum = dmd_scripts.Dynamics(H_custom,Eigvals,Modes,nt,d)
# Out:
# dmd_timesteps: 120
# original_time: {'t0': 0, 'tend': 119, 'dt': 1}
# /home/juanmosquera/Library/PyDMD/pydmd/snapshots.py:73: UserWarning: Input data condition number 1.539994674102876e+17. Consider preprocessing data, passing in augmented data
# matrix, or regularization methods.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 12))

plt.subplot(3, 2, 1)
plt.title("Eigenvalues: Custom vs PyDMD")
plt.plot(lead_eigs.real, lead_eigs.imag, 'go', label='PyDMD')
plt.plot(Eigvals.real, Eigvals.imag, 'r*', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 2)
plt.title("Singular Values")
plt.plot(np.log(Singular_values[:]/Singular_values[0]), 'g.', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 3)
plt.title("Eigenmodes")
plt.plot(dmd.amplitudes.real,dmd.amplitudes.imag, 'go', label='PyDMD')
plt.plot(amplitudes_costum.real, amplitudes_costum.imag, 'r*', label='Custom')
plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 4)
plt.imshow(np.dot(modes_average,b_costum).real)

plt.subplot(3, 2, 5)
plt.imshow(delay_dmd.reconstructed_data[0:65].real)

plt.subplot(3, 2, 6)
plt.imshow(reconstruction_costum[:,0:120].real)

# %%
plotting.plot_singular_values(Singular_values,10**(-2))
plotting.plot_eigenvalues(Eigvals)
plotting.plot_amplitudes_b(amplitudes_costum)
plotting.plot_modes_vs_grid(modes_average,0,np.array([[-5,5],[-0.1,0.1]]),x,ky=None,dimension=1)

# %%
def Dynamics(H,Eigvals,Modes,nt,d):
    x1=H[:,0]

    #if d > 1:
    Φ = np.average( Modes.reshape(d,Modes.shape[0] // d, Modes.shape[1],),axis=0,)

    time_steps = np.linspace(0,nt,nt+1,dtype=int)
    temp = np.repeat( Eigvals[:, None], time_steps.shape[0], axis=1 )
    tpow = ( time_steps - 0 ) / ( time_steps[1] - time_steps[0] )

    amplitudes = LA.pinv(Modes) @ x1
    dynamics = np.power(temp, tpow) * amplitudes[:, None]

    return temp, amplitudes, dynamics , np.dot(Φ,dynamics)

d=4
H_custom = dmd_scripts.custom_hankel_embedding(X.T, d)
Singular_values,Eigvals,Modes,modes_average = dmd_scripts.perform_dmd(H_custom, rank=rank, d=d )
temp_costum,amplitudes_costum,b_costum,reconstruction_costum = Dynamics(H_custom,Eigvals,Modes,nt,d)


plt.figure(figsize=(12, 12))

plt.subplot(3, 2, 1)
plt.title("Eigenvalues: Custom vs PyDMD")
plt.plot(lead_eigs.real, lead_eigs.imag, 'go', label='PyDMD')
plt.plot(Eigvals.real, Eigvals.imag, 'r*', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 2)
plt.title("Singular Values")
plt.plot(np.log(Singular_values[:]/Singular_values[0]), 'g.', label='Custom')

plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 3)
plt.title("Eigenmodes")
plt.plot(dmd.amplitudes.real,dmd.amplitudes.imag, 'go', label='PyDMD')
plt.plot(amplitudes_costum.real, amplitudes_costum.imag, 'r*', label='Custom')
plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.grid(True)
plt.legend()

plt.subplot(3, 2, 4)
plt.imshow(np.dot(modes_average,b_costum).real)

plt.subplot(3, 2, 5)
#plt.imshow(delay_dmd.reconstructed_data[0:65].real)
plt.plot(delay_dmd.reconstructed_data[0].real)

plt.subplot(3, 2, 6)
#plt.imshow(reconstruction_costum[:,0:129].real)
plt.plot(np.linspace(0,129,129),delay_dmd.reconstructed_data[45].real)
plt.plot(np.linspace(0,129,129)+1,reconstruction_costum[45,0:129].real)
