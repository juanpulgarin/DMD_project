# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import scipy.linalg as LA

import Hamiltonian as Hamiltonian
import DMD_scripts as dmd_scripts
import Plotting as plotting
import constants as cst


from pydmd import DMD, BOPDMD
from pydmd.plotter import plot_eigs, plot_summary
from pydmd.preprocessing import hankel_preprocessing

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ### This section shows what happens when changing the different parameters in your Hamiltonian

# %%
k_vals = np.linspace(-np.pi, np.pi, 101)[:-1]

J_list     = np.array([1.0])/cst.Ry
delta_list = np.array([0.5,1.5])/cst.Ry

valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-3.5,3.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')

for J in J_list:
    for Δ in delta_list:
        plotting.plot_band_structure(k_vals, np.array([J]), np.array([Δ]), valence_bands, conduction_bands, limits,fout='')



J_list     = np.array([1.0,2.5])/cst.Ry
delta_list = np.array([0.5])/cst.Ry


valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-3.5,3.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')

for J in J_list:
    for Δ in delta_list:
        plotting.plot_band_structure(k_vals, np.array([J]), np.array([Δ]), valence_bands, conduction_bands, limits,fout='')

# %% [markdown]
# ### Fix a set of parameters for the Bands, then change the values of the Field and the case

# %%
k_vals = np.linspace(-np.pi, np.pi, 101)[:-1]

J_list     = np.array([0.5])/cst.Ry
delta_list = np.array([0.5])/cst.Ry

valence_bands    = {}
conduction_bands = {}
for J in J_list:
    for Δ in delta_list:
        valence_bands[J,Δ]    = Hamiltonian.eps_vb( k_vals, J, Δ )
        conduction_bands[J,Δ] = Hamiltonian.eps_cb( k_vals, J, Δ )

limits=np.array([[-np.pi,np.pi],[-2.5,2.5]])

plotting.plot_band_structure(k_vals, J_list, delta_list, valence_bands, conduction_bands, limits,fout='')
# Out:
# 0

# %%
case=1

t = np.linspace(0, 100, 10000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 2.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J     = 0.5/cst.Ry
delta = 0.5/cst.Ry
#k_list=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8]
k_list=np.linspace(0,0.75,40)


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),2,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]

# %%
limits=np.array([[0,100],[0.0,0.2]])
plotting.plot_population_field(t*cst.tfs,efield,k_list,solutions.real,limits)
# Out:
# 0

# %%
case=2

t = np.linspace(0, 500, 5000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 0.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J     = 0.5/cst.Ry
delta = 0.5/cst.Ry
k_list=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85]


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),3,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]
    solutions[k_i,2,:] = sol.y[3]

# %%
plt.figure()

for i in range(len(k_list)):
    plt.plot(solutions[i,2,:].imag)

print(np.shape(solutions[:,2,:]))
# Out:
# (9, 5000)

# %%
limits=np.array([[0,100],[0.0,0.2]])
plotting.plot_population_field(t*cst.tfs,efield,k_list,solutions.real,limits)
# Out:
# 0

# %% [markdown]
# ### After fixing a case, test the DMD algorithm

# %%
case=1

t = np.linspace(0, 100, 10000)/ cst.tfs

FWHM  = 20. / cst.tfs
sigma = FWHM/(2.0*np.sqrt(2*np.log(2)))
E0 = 1.7

efield = Hamiltonian.E(t, sigma,E0, ω=0.5/cst.Ry, case=case )
#plotting.plot_electric_pulse(t*cst.tfs, efield, np.array([[0,100],[-0.002*0,0.002]]),fout='')

J      = 0.5/cst.Ry
delta  = 0.5/cst.Ry
k_list = np.linspace(-np.pi, np.pi, 101)[:-1]


t_span= (t[0],t[-1])


solutions=np.zeros((len(k_list),2,len(t)),dtype=np.complex64)
for k_i,k in enumerate(k_list):
    y0 = np.array([1.0, 0.0, 0.0, 0.0], dtype=complex)
    sol = solve_ivp(lambda t, y: Hamiltonian.rhs(t, y, k, J, delta, sigma, E0, ω=0.5/cst.Ry,case=case), t_span, y0, t_eval=t)
    solutions[k_i,0,:] = sol.y[0]
    solutions[k_i,1,:] = sol.y[1]

# %%
limits=np.array([[0,100],[0.0,0.2]])
plotting.plot_population_field(t*cst.tfs,efield,k_list,solutions.real,limits)
# Out:
# 0

# %% [markdown]
# ## First test using Tutorial 1

# %% [markdown]
# ## Second test using Tutorial 2

# %%
# Define parameters
dmd_rank = 50
delay_embedding_dim = 100 # Set to 0 for no Hankel embedding

dmd = dmd_lib.DMD(rank=dmd_rank, delay_embedding_dim=delay_embedding_dim)
dmd.fit(solutions[:,2,:])
# Out:
# 5000

# %%
plotting.plot_singular_values(dmd.S,dmd_rank)
plotting.plot_eigenvalues(dmd.eigvals)
plotting.plot_amplitudes_b(dmd.amplitudes_costum)
plotting.plot_modes_vs_grid(dmd.Phi_physical,0,np.array([[0,1],[-0.1,0.1]]),k_list,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,1,np.array([[0,1],[-0.1,0.1]]),k_list,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,2,np.array([[0,1],[-0.1,0.1]]),k_list,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,3,np.array([[0,1],[-0.1,0.1]]),k_list,dimension=1)

plotting.plot_modes_vs_time(dmd.dynamics_custom,0,np.array([[0,130],[-10,10]]))
plotting.plot_comparison_data_1d(solutions[:,2,:],dmd.reconstructed_X,8,np.array([[0,5000],[-0.05,0.05]]))
# Out:
# 0

# %%
import numpy as np
import scipy.linalg as LA
from scipy.linalg import svd, eig, pinv
from scipy.optimize import lsq_linear # New import for lsq_linear
import matplotlib.pyplot as plt

# 1. User's provided function for Hankel embedding
def custom_hankel_embedding(X, delay):
    """
    Performs Hankel embedding on the input data X.

    Parameters:
    X (np.ndarray): The input data matrix (spatial_points, time_steps).
                    Each column is a snapshot.
    delay (int): The embedding dimension (number of time delays).

    Returns:
    np.ndarray: The Hankel embedded matrix.
                Shape: (spatial_points * delay, time_steps - delay + 1).
    """
    if delay == 0: # Handle the case where no embedding is requested
        return X

    n_spatial, n_time = X.shape
    
    if n_time < delay:
        raise ValueError(f"Number of time steps ({n_time}) is less than the delay embedding dimension ({delay}). Cannot perform Hankel embedding.")

    hankel_matrix_rows = []
    # Iterate 'delay' times to create the stacked Hankel blocks
    for i in range(delay):
        hankel_matrix_rows.append(X[:, i : n_time - delay + i + 1])

    hankel_matrix = np.vstack(hankel_matrix_rows)
    return hankel_matrix

# 2. User's provided function for performing DMD
def perform_dmd(H, rank=None, delay_embedding_dim=1, tikhonov_regularization=None):
    """
    Performs Dynamic Mode Decomposition (DMD) on a Hankel embedded matrix.

    Parameters:
    H (np.ndarray): The Hankel embedded data matrix.
    rank (int, optional): The truncation rank for SVD. If None, rank is determined automatically.
    delay_embedding_dim (int): The embedding dimension used in Hankel embedding.
                               Used to reshape modes for physical interpretation.
                               Note: This parameter's default value will be overridden if
                               the calling context (e.g., main script or class) passes
                               a different value. It's used here for reshaping Phi_physical.
    tikhonov_regularization (float, optional): Regularization parameter for the
                                                pseudoinverse (modifies singular values).

    Returns:
    tuple: (S, eigvals, Phi_full, Phi_physical)
        S (np.ndarray): Singular values from SVD of X1.
        eigvals (np.ndarray): DMD eigenvalues (discrete-time).
        Phi_full (np.ndarray): Full DMD modes in the embedded (Hankel) space.
        Phi_physical (np.ndarray): Averaged/physical DMD modes (reshaped to original spatial dim).
    """

    X1 = H[:, :-1]
    X2 = H[:, 1:]

    # Singular Value Decomposition (SVD) of X1
    # U: Left singular vectors (spatial basis for X1)
    # S: Singular values
    # Vh: Conjugate transpose of right singular vectors (temporal basis for X1)
    U, S, Vh = np.linalg.svd(X1, full_matrices=False)

    V = Vh.conj().T

    # Determine truncation rank if not explicitly provided
    if rank is None:
        # A simple heuristic: select rank that captures a significant portion of energy
        r_threshold = 0.01
        rank = np.sum(S > S[0] * r_threshold)
        if rank == 0: # Ensure at least one mode is selected
            rank = 1
        print(f"Automatically determined rank for DMD: {rank}")

    U_r  = U[:, :rank]
    S_r  = S[:rank]
    V_r = V[:, :rank]

    # Apply Tikhonov regularization if a parameter is provided
    if tikhonov_regularization is not None:
        norm_X = np.linalg.norm(X1, 'fro') # Use Frobenius norm for X1
        # Modify singular values for regularization: S_r_reg = (S_r**2 + lambda * ||X||_F) / S_r
        S_r_reg = (S_r**2 + tikhonov_regularization * norm_X) / S_r
        # Create inverse of regularized singular values, adding a small epsilon for stability
        Sigma_inv = np.diag(1.0 / (S_r_reg + 1e-10))
    else:
        Sigma_inv = np.diag(1.0 / (S_r + 1e-10))

    # Compute the Koopman operator (or its finite-dimensional approximation, A_tilde)
    # A_tilde = U_r^* X2 V_r Sigma_inv
    A_tilde = U_r.conj().T @ X2 @ V_r @ Sigma_inv

    eigvals, W = LA.eig(A_tilde)

    # Compute the full DMD modes (Phi_full) in the embedded (Hankel) state space
    #Phi_full = X2 @ V_r @ Sigma_inv @ W
    Phi_full = U_r.dot(W)

    # The actual delay used for embedding might be 1 even if delay_embedding_dim was 0,
    # as H would be the original matrix. For reshaping Phi_physical, we need to know
    # how many "blocks" there are in Phi_full that correspond to the *original* spatial dimension.
    # If delay_embedding_dim was 0, it means no actual embedding, so it's a single "block".
    effective_delay_for_physical_modes = delay_embedding_dim if delay_embedding_dim > 0 else 1
    
    num_spatial_points_original = Phi_full.shape[0] // effective_delay_for_physical_modes
    Phi_physical = np.average(
        Phi_full.reshape(effective_delay_for_physical_modes, num_spatial_points_original, Phi_full.shape[1]),
        axis=0
    )

    return S, eigvals, Phi_full, Phi_physical

# New function for least squares amplitude calculation (LEAST_OUTER)
def LEAST_OUTER(D, Phi, mu, tspan, dt, r):
    # Get dimensions
    n_rows, len_tspan = np.shape(D)
    dim_outer_space = len_tspan * n_rows

    # Flatten real and imaginary parts of D
    xbig_real = np.real(D).flatten()
    xbig_imag = np.imag(D).flatten()

    # Concatenate real and imaginary parts into x_big
    x_big = np.concatenate((xbig_real, xbig_imag))

    # Precompute exponentials
    t_diff = tspan - tspan[0]
    # CORRECTED LINE: Scale t_diff by dt to get the number of discrete steps
    exp_terms = np.exp(np.log(mu[:, np.newaxis]) * (t_diff[np.newaxis, :] / dt))

    # Initialize Gbig_real and Gbig_imag
    Gbig_real = np.zeros((dim_outer_space, r))
    Gbig_imag = np.zeros((dim_outer_space, r))

    # Fill Gbig_real and Gbig_imag using broadcasting and reshaping
    for nu_i in range(r):
        # Phi is Modes (i.e., Phi_full in the main script)
        # It has shape (embedded_spatial_dim, rank)
        Phi_exp = Phi[:, nu_i][:, np.newaxis] * exp_terms[nu_i]
        Gbig_real[:, nu_i] = np.real(Phi_exp).flatten()
        Gbig_imag[:, nu_i] = np.imag(Phi_exp).flatten()

    # Assemble Gbig
    Gbig = np.zeros((2 * dim_outer_space, 2 * r), dtype=float)
    Gbig[0:dim_outer_space, 0:r] = Gbig_real
    Gbig[dim_outer_space:, r:2*r] = Gbig_real
    Gbig[0:dim_outer_space, r:2*r] = -Gbig_imag
    Gbig[dim_outer_space:, 0:r] = Gbig_imag

    # Solve the least squares problem
    sol = lsq_linear(Gbig, x_big)

    # Construct the result
    b_new = sol.x[:r] + 1.0j * sol.x[r:2*r]

    return b_new


# 3. User's provided function for reconstructing dynamics
def Dynamics(H, Eigvals, Modes, nt, d, original_time_tspan, amplitudes_method='pinv'):
    """
    Reconstructs the dynamics using DMD modes and eigenvalues, along with initial amplitudes.
    This function specifically replicates the logic and variable usage from the user's provided
    Dynamics function, with a correction for the 'dynamics' calculation.

    Parameters:
    H (np.ndarray): The full Hankel embedded data matrix. Its first column (H[:,0])
                    is used as the initial state.
    Eigvals (np.ndarray): DMD eigenvalues (discrete-time).
    Modes (np.ndarray): Full DMD modes in the embedded space (Phi_full from perform_dmd).
    nt (int): The number of time steps (length of the original time array).
              Used to determine the length of the reconstruction.
    d (int): The embedding dimension used in Hankel embedding. Used for slicing 'physical_modes'.
    original_time_tspan (np.ndarray): The original time array for the full data.
    amplitudes_method (str): Method to calculate amplitudes. 'pinv' (default) or 'least_outer'.

    Returns:
    tuple: (dynamics, amplitudes, reconstructed_data)
        dynamics (np.ndarray): The time dynamics of each DMD mode.
        amplitudes (np.ndarray): The initial amplitudes of each DMD mode.
        reconstructed_data (np.ndarray): The reconstructed data in the original spatial dimension.
    """
    x1 = H[:, 0] # Initial state of the embedded system (first column of Hankel matrix)

    # Replicate user's 'physical_modes' calculation (first block of Modes)
    # Note: 'd' here is the delay_embedding_dim. If d was 0, it means no embedding,
    # so the effective d for slicing would be 1 (original spatial dimension)
    effective_d_for_physical_modes = d if d > 0 else 1
    num_spatial_points_original = Modes.shape[0] // effective_d_for_physical_modes
    physical_modes = Modes[0:num_spatial_points_original, :]

    # Replicate user's 'time_steps' and 'tpow' calculation
    time_steps = np.linspace(0, nt - 1, nt, dtype=int)
    if nt > 1:
        tpow = (time_steps - 0) / (time_steps[1] - time_steps[0])
    else:
        tpow = np.array([0])

    # Calculate amplitudes based on chosen method
    if amplitudes_method == 'least_outer':
        # Calculate dt from the original time array
        dt_val = original_time_tspan[1] - original_time_tspan[0] if len(original_time_tspan) > 1 else 1.0
        # Pass the full embedded matrix H as D, and Phi_full (Modes) as Phi
        amplitudes = LEAST_OUTER(
            D=H, # Pass the full embedded matrix H as D for LEAST_OUTER
            Phi=Modes, # Pass the full embedded modes (Modes)
            mu=Eigvals,
            tspan=original_time_tspan[:H.shape[1]], # CORRECTED LINE: Slice tspan to match H's time dimension
            dt=dt_val,
            r=len(Eigvals) # Rank 'r' is the number of eigenvalues
        )
    else: # Default or 'pinv' method
        amplitudes = LA.pinv(Modes) @ x1

    dynamics = np.power(Eigvals[:, None], tpow[None, :]) * amplitudes[:, None]

    reconstructed_data = np.dot(physical_modes, dynamics)

    return dynamics, amplitudes, reconstructed_data

# Main script integration for demonstration
print("Generating original data...")
x1 = np.linspace(-3, 3, 80)
x2 = np.linspace(-3, 3, 80)
x1grid, x2grid = np.meshgrid(x1, x2)
time = np.linspace(0, 12, 260) # Total time steps (nt = 260)

data_clean = [2 / np.cosh(x1grid) / np.cosh(x2grid) * (1.2j**-t) for t in time]
noise = [np.random.normal(0.0, 0.4, size=x1grid.shape) for _ in time]
data_noisy = [d + n * 0. for d, n in zip(data_clean, noise)]

full_data_matrix = np.array([snapshot.flatten() for snapshot in data_noisy]).T
print(f"Shape of full_data_matrix (Original): {full_data_matrix.shape}")

# Define parameters
dmd_rank = 1
delay_embedding_dim = 10 # Changed to 10 to test the scenario that caused the error
# Choose amplitude calculation method: 'pinv' (default) or 'least_outer'
amplitude_calculation_method = 'least_outer' # Changed to 'least_outer' for demonstration

# --- DMD Workflow using the standalone functions ---

# Step 1: Perform Hankel embedding
print(f"\nPerforming Hankel embedding with delay = {delay_embedding_dim}...")
# custom_hankel_embedding will now correctly return full_data_matrix if delay_embedding_dim is 0
H_embedded_matrix = custom_hankel_embedding(full_data_matrix, delay=delay_embedding_dim)
print(f"Shape of Hankel matrix H: {H_embedded_matrix.shape}")

# Step 2: Perform DMD on the Hankel embedded data
print(f"Performing DMD with rank = {dmd_rank}...")
# Pass the correct delay_embedding_dim to perform_dmd for Phi_physical reshaping logic
S, eigvals, Phi_full, Phi_physical = perform_dmd(
    H=H_embedded_matrix, rank=dmd_rank, delay_embedding_dim=delay_embedding_dim
)
print(f"DMD Eigenvalues: {eigvals}")
print(f"Shape of Full DMD Modes (Phi_full, embedded space): {Phi_full.shape}")
print(f"Shape of Physical DMD Modes (Phi_physical, original space): {Phi_physical.shape}")

# Step 3: Reconstruct the data using DMD dynamics
print(f"Reconstructing data using DMD dynamics with amplitudes_method='{amplitude_calculation_method}'...")
# Pass the correct delay_embedding_dim to Dynamics for physical_modes slicing
dynamics_result, amplitudes_result, reconstructed_X_result = Dynamics(
    H=H_embedded_matrix,
    Eigvals=eigvals,
    Modes=Phi_full,
    nt=len(time),
    d=delay_embedding_dim, # Pass the original delay_embedding_dim
    original_time_tspan=time, # Pass the original time array
    amplitudes_method=amplitude_calculation_method
)
print(f"Shape of Reconstructed Data: {reconstructed_X_result.shape}")

print("\nDMD process completed. Visualizing results...")

# Basic visualization for first snapshot (Magnitude)
reconstructed_snapshot_0 = reconstructed_X_result[:, 0].reshape(x1grid.shape)
original_snapshot_0 = data_noisy[0]

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.pcolormesh(x1grid, x2grid, np.abs(original_snapshot_0), shading='auto')
plt.title('Original First Snapshot (Magnitude)')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.pcolormesh(x1grid, x2grid, np.abs(reconstructed_snapshot_0), shading='auto')
plt.title('DMD Reconstructed First Snapshot (Magnitude)')
plt.colorbar()

plt.tight_layout()
plt.show()

# Extra plot: Original data point (40, 40) as a function of time vs. DMD reconstruction
spatial_point_row_idx = 39
spatial_point_col_idx = 39
flattened_index = spatial_point_row_idx * x2.size + spatial_point_col_idx

original_point_time_series = np.array([snapshot.flatten()[flattened_index] for snapshot in data_noisy])
reconstructed_point_time_series = reconstructed_X_result[flattened_index, :]

plt.figure(figsize=(10, 6))
plt.plot(time, np.abs(original_point_time_series), label='Original Data (Magnitude)', linestyle='-')
plt.plot(time, np.abs(reconstructed_point_time_series), label='DMD Reconstruction (Magnitude)', linestyle='--')
plt.title(f'Time Evolution of Spatial Point ({spatial_point_row_idx+1}, {spatial_point_col_idx+1}) - Magnitude')
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.legend()
plt.grid(True)
plt.show()

print("Further analysis can be performed on the DMD modes, eigenvalues, and reconstruction quality.")
# Out:
# Generating original data...
# Shape of full_data_matrix (Original): (6400, 260)
#
# Performing Hankel embedding with delay = 10...
# Shape of Hankel matrix H: (64000, 251)
# Performing DMD with rank = 1...
# DMD Eigenvalues: [0.98896335-0.07210233j]
# Shape of Full DMD Modes (Phi_full, embedded space): (64000, 1)
# Shape of Physical DMD Modes (Phi_physical, original space): (6400, 1)
# Reconstructing data using DMD dynamics with amplitudes_method='least_outer'...
# Shape of Reconstructed Data: (6400, 260)
#
# DMD process completed. Visualizing results...
# Further analysis can be performed on the DMD modes, eigenvalues, and reconstruction quality.

# %%
import numpy as np
import mosqDMD_class as dmd_lib
import Plotting as plotting
import matplotlib.pyplot as plt

# Main script integration for demonstration
print("Generating original data...")
x1 = np.linspace(-3, 3, 80)
x2 = np.linspace(-3, 3, 80)
x1grid, x2grid = np.meshgrid(x1, x2)
time = np.linspace(0, 12, 260) # Total time steps (nt = 260)

data_clean = [2 / np.cosh(x1grid) / np.cosh(x2grid) * (1.2j**-t) for t in time]
noise = [np.random.normal(0.0, 0.1, size=x1grid.shape) for _ in time]
data_noisy = [d + n * 1. for d, n in zip(data_clean, noise)]

full_data_matrix = np.array([snapshot.flatten() for snapshot in data_noisy]).T
print(f"Shape of full_data_matrix (Original): {full_data_matrix.shape}")
# Out:
# Generating original data...
# Shape of full_data_matrix (Original): (6400, 260)

# %%
# Define parameters
dmd_rank = 1
delay_embedding_dim = 10 # Set to 0 for no Hankel embedding
# Choose amplitude calculation method: 'pinv' (default) or 'least_outer'
amplitude_calculation_method = 'least_outer'
frequencies_for_omega_reconstruction = np.linspace(-2*np.pi, 2*np.pi, 1000)
num_future_steps_to_reconstruct = 60

dmd = dmd_lib.DMD(rank=dmd_rank, delay_embedding_dim=delay_embedding_dim,\
                  amplitudes_method=amplitude_calculation_method,frequencies=frequencies_for_omega_reconstruction)
dmd.fit(full_data_matrix, time,num_future_steps=num_future_steps_to_reconstruct)




dmd_with_tlsq = dmd_lib.DMD(rank=dmd_rank, delay_embedding_dim=delay_embedding_dim,\
                  amplitudes_method=amplitude_calculation_method,frequencies=frequencies_for_omega_reconstruction,tlsq_rank=10)
dmd_with_tlsq.fit(full_data_matrix, time,num_future_steps=num_future_steps_to_reconstruct)
# Out:
# Applying TLSQ denoising with rank=10...

# %%
plotting.plot_singular_values(dmd.S,dmd_rank)
plotting.plot_eigenvalues(dmd.eigvals)
plotting.plot_amplitudes_b(dmd.amplitudes_custom)
plotting.plot_modes_vs_grid(np.reshape(dmd.Phi_physical,[80,80,dmd_rank]),0,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
#plotting.plot_modes_vs_grid(np.reshape(dmd.Phi_physical,[80,80,dmd_rank]),1,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
#plotting.plot_modes_vs_grid(np.reshape(dmd.Phi_physical,[80,80,dmd_rank]),2,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
plotting.plot_modes_vs_time(dmd.dynamics_custom,0,np.array([[0,300],[-200,200]]))
plotting.plot_comparison_data_1d(full_data_matrix,dmd.reconstructed_X,20,np.array([[0,350],[-0.5,0.5]]))
plotting.plot_frequencies_1d(dmd.reconstructed_omega,10,frequencies_for_omega_reconstruction,np.array([[-np.pi,np.pi],[-5,5]]))
# Out:
# 0

# %%
plotting.plot_singular_values(dmd_with_tlsq.S,dmd_rank)
plotting.plot_eigenvalues(dmd_with_tlsq.eigvals)
plotting.plot_amplitudes_b(dmd_with_tlsq.amplitudes_custom)
plotting.plot_modes_vs_grid(np.reshape(dmd_with_tlsq.Phi_physical,[80,80,dmd_rank]),0,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
#plotting.plot_modes_vs_grid(np.reshape(dmd.Phi_physical,[80,80,dmd_rank]),1,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
#plotting.plot_modes_vs_grid(np.reshape(dmd.Phi_physical,[80,80,dmd_rank]),2,np.array([[-5,5],[-0.1,0.1]]),x1,ky=x2,dimension=2)
plotting.plot_modes_vs_time(dmd_with_tlsq.dynamics_custom,0,np.array([[0,300],[-200,200]]))
plotting.plot_comparison_data_1d(full_data_matrix,dmd_with_tlsq.reconstructed_X,20,np.array([[0,350],[-0.4,0.4]]))
plotting.plot_frequencies_1d(dmd_with_tlsq.reconstructed_omega,10,frequencies_for_omega_reconstruction,np.array([[-np.pi,np.pi],[-5,5]]))
# Out:
# 0

# %%
def f1(x, t):
    return 1.0 / np.cosh(x + 3) * np.cos(2.3 * t)


def f2(x, t):
    return 2.0 / np.cosh(x) * np.tanh(x) * np.sin(2.8 * t)


nx = 65  # number of grid points along space dimension
nt = 129  # number of grid points along time dimension

# Define the space and time grid for data collection.
x = np.linspace(-5, 5, nx)
t = np.linspace(0, 4 * np.pi, nt)
xgrid, tgrid = np.meshgrid(x, t)
dt = t[1] - t[0]  # time step between each snapshot

# Data consists of 2 spatiotemporal signals.
X1 = f1(xgrid, tgrid)
X2 = f2(xgrid, tgrid)
X = X1 + X2

# Make a version of the data with noise.
mean = 0
std_dev = 0.2
random_matrix = np.random.normal(mean, std_dev, size=(nt, nx))

print(np.shape(X))
# Out:
# (129, 65)

# %%
dmd_rank = 4
delay_embedding_dim = 4 # Set to 0 for no Hankel embedding
amplitude_calculation_method = 'least_outer' # Changed to 'least_outer' for demonstration
frequencies_for_omega_reconstruction = np.linspace(-2*np.pi, 2*np.pi, 2000)
num_future_steps_to_reconstruct = 40
dmd = dmd_lib.DMD(rank=dmd_rank, delay_embedding_dim=delay_embedding_dim,\
                  amplitudes_method=amplitude_calculation_method,frequencies=frequencies_for_omega_reconstruction)
dmd.fit(X.T, t,num_future_steps=num_future_steps_to_reconstruct) # Pass the time array to the fit method
# Out:
# Omega_DMD_Continuous_Freqs: [-3.58042111e-11+2.8j -3.58042111e-11-2.8j -4.84347239e-11+2.3j
#  -4.84347239e-11-2.3j]
# Max Delta_Omega: 63.211178886965826
# dt_val: 0.09817477042468103
# Calculated Sigma for Delta_Frequency: 0.006286328471415294
# Max Data_Frequency: (74.14710176330503-1.482150884910971e-10j)

# %%
import Plotting as plotting


plotting.plot_singular_values(dmd.S,dmd_rank)
plotting.plot_eigenvalues(dmd.eigvals)
plotting.plot_amplitudes_b(dmd.amplitudes_custom)
plotting.plot_modes_vs_grid(dmd.Phi_physical,0,np.array([[-5,5],[-0.1,0.1]]),x,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,1,np.array([[-5,5],[-0.1,0.1]]),x,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,2,np.array([[-5,5],[-0.1,0.1]]),x,dimension=1)
plotting.plot_modes_vs_grid(dmd.Phi_physical,3,np.array([[-5,5],[-0.1,0.1]]),x,dimension=1)

plotting.plot_modes_vs_time(dmd.dynamics_custom,0,np.array([[0,130],[-10,10]]))
plotting.plot_comparison_data_1d(X.T,dmd.reconstructed_X,20,np.array([[0,170],[-5,5]]))

plotting.plot_comparison_data_2d(X.T,dmd.reconstructed_X,x,t,np.array([[0,170],[-5,5]]))
plotting.plot_frequencies_1d(dmd.reconstructed_omega,10,frequencies_for_omega_reconstruction,np.array([[-2*np.pi,2*np.pi],[-5,5]]))
plotting.plot_frequencies_2d(dmd.reconstructed_omega,x,frequencies_for_omega_reconstruction,np.array([[-2*np.pi,2*np.pi],[-5,5]]))
# Out:
# 0
